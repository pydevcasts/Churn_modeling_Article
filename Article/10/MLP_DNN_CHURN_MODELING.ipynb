# %% [markdown]
# ## MLP K_FOLD Compelete

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import StratifiedKFold
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.metrics import roc_curve, auc, confusion_matrix, precision_score, recall_score, f1_score
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import RMSprop

# Load dataset
dataset = pd.read_csv("/content/Churn_Modelling.csv")
dataset = dataset.drop(['RowNumber', 'CustomerId', 'Surname'], axis=1)

# Encode categorical features
for col in ['Geography', 'Gender']:
    le = LabelEncoder()
    dataset[col] = le.fit_transform(dataset[col])

# Split features and target
X = dataset.drop("Exited", axis=1).values
y = dataset["Exited"].values

# Standardize features
scaler = StandardScaler()
X = scaler.fit_transform(X)

# Initialize K-fold cross-validation
kfold = StratifiedKFold(n_splits=10, shuffle=True, random_state=42)

# Metric storage
accuracy_scores = []
precision_scores = []
recall_scores = []
f1_scores = []

# Cross-validation loop
for fold_idx, (train_index, test_index) in enumerate(kfold.split(X, y)):
    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = y[train_index], y[test_index]

    # Build model
    model = Sequential()
    model.add(Dense(6, input_dim=X.shape[1], activation='sigmoid'))
    model.add(Dense(6, activation='sigmoid'))
    model.add(Dense(1, activation='sigmoid'))

    model.compile(optimizer=RMSprop(learning_rate=0.01),
                  loss='binary_crossentropy',
                  metrics=['accuracy'])

    # Train model
    history = model.fit(X_train, y_train, epochs=30, batch_size=7, verbose=1, validation_split=0.1)

    # Evaluate model
    _, acc = model.evaluate(X_test, y_test, verbose=1)
    accuracy_scores.append(acc)

    # Predict
    y_pred_prob = model.predict(X_test).ravel()
    y_pred_class = (y_pred_prob > 0.5).astype(int)

    # Calculate metrics
    precision = precision_score(y_test, y_pred_class)
    recall = recall_score(y_test, y_pred_class)
    f1 = f1_score(y_test, y_pred_class)

    precision_scores.append(precision)
    recall_scores.append(recall)
    f1_scores.append(f1)

    # Plot only for the first fold
    if fold_idx == 0:
        # Accuracy curve
        plt.figure(figsize=(8, 5))
        plt.plot(history.history['accuracy'], label='Train Accuracy')
        plt.plot(history.history['val_accuracy'], label='Val Accuracy')
        plt.title('Accuracy over Epochs')
        plt.xlabel('Epochs')
        plt.ylabel('Accuracy')
        plt.legend()
        plt.grid(True)
        plt.show()

        # ROC Curve
        fpr, tpr, thresholds = roc_curve(y_test, y_pred_prob)
        roc_auc = auc(fpr, tpr)

        plt.figure(figsize=(6, 6))
        plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'ROC Curve (AUC = {roc_auc:.2f})')
        plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
        plt.xlabel('False Positive Rate')
        plt.ylabel('True Positive Rate')
        plt.title('ROC Curve')
        plt.legend(loc='lower right')
        plt.grid(True)
        plt.show()

        # Confusion Matrix
        cm = confusion_matrix(y_test, y_pred_class)

        plt.figure(figsize=(5, 4))
        sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
                    xticklabels=['Not Churn', 'Churn'],
                    yticklabels=['Not Churn', 'Churn'])
        plt.xlabel('Predicted')
        plt.ylabel('True')
        plt.title('Confusion Matrix')
        plt.show()

# Final results
print("\nFinal Evaluation on Test Set (10-fold Cross-Validation):")
print(f"Accuracy  : {np.mean(accuracy_scores) * 100:.2f}%")
print(f"Precision : {np.mean(precision_scores) * 100:.2f}%")
print(f"Recall    : {np.mean(recall_scores) * 100:.2f}%")
print(f"F1 Score  : {np.mean(f1_scores) * 100:.2f}%")
# Out:
# Epoch 1/30
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1158/1158 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.7886 - loss: 0.4732 - val_accuracy: 0.8389 - val_loss: 0.4083
# Epoch 2/30
# 1158/1158 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8245 - loss: 0.4276 - val_accuracy: 0.8400 - val_loss: 0.4008
# Epoch 3/30
# 1158/1158 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8349 - loss: 0.4041 - val_accuracy: 0.8400 - val_loss: 0.3980
# Epoch 4/30
# 1158/1158 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8372 - loss: 0.4047 - val_accuracy: 0.8467 - val_loss: 0.3955
# Epoch 5/30
# ...

# %% [markdown]
# ## DNN

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import StratifiedKFold
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.metrics import (roc_curve, auc, confusion_matrix,
                             precision_score, recall_score, f1_score)
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import RMSprop

# خواندن داده‌ها
dataset = pd.read_csv("/content/Churn_Modelling.csv")
dataset = dataset.drop(['RowNumber', 'CustomerId', 'Surname'], axis=1)

# Label Encoding
for col in ['Geography', 'Gender']:
    le = LabelEncoder()
    dataset[col] = le.fit_transform(dataset[col])

# ویژگی‌ها و برچسب‌ها
X = dataset.drop("Exited", axis=1).values
y = dataset["Exited"].values

# استانداردسازی
scaler = StandardScaler()
X = scaler.fit_transform(X)

# Cross-validation
kfold = StratifiedKFold(n_splits=10, shuffle=True, random_state=42)

accuracy_scores = []
precision_scores = []
recall_scores = []
f1_scores = []

for fold_idx, (train_index, test_index) in enumerate(kfold.split(X, y)):
    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = y[train_index], y[test_index]

    # مدل DNN
    model = Sequential()
    model.add(Dense(10, activation='relu', input_shape=(X.shape[1],)))
    model.add(Dense(6, activation='relu'))
    model.add(Dense(6, activation='relu'))
    model.add(Dense(1, activation='sigmoid'))

    model.compile(optimizer=RMSprop(learning_rate=0.01),
                  loss='binary_crossentropy',
                  metrics=['accuracy'])

    history = model.fit(X_train, y_train, epochs=30, batch_size=7,
                        validation_split=0.1, verbose=1)

    _, accuracy = model.evaluate(X_test, y_test, verbose=1)

    # پیش‌بینی برای محاسبه معیارها
    y_pred_prob = model.predict(X_test).ravel()
    y_pred_class = (y_pred_prob > 0.5).astype(int)

    precision = precision_score(y_test, y_pred_class)
    recall = recall_score(y_test, y_pred_class)
    f1 = f1_score(y_test, y_pred_class)

    accuracy_scores.append(accuracy)
    precision_scores.append(precision)
    recall_scores.append(recall)
    f1_scores.append(f1)

    # فقط برای fold اول نمودار بکش
    if fold_idx == 0:
        # 1. نمودار دقت
        plt.figure(figsize=(8,5))
        plt.plot(history.history['accuracy'], label='Train Accuracy')
        plt.plot(history.history['val_accuracy'], label='Val Accuracy')
        plt.title('DNN Accuracy over Epochs')
        plt.xlabel('Epochs')
        plt.ylabel('Accuracy')
        plt.legend()
        plt.grid(True)
        plt.show()

        # 2. ROC و AUC
        fpr, tpr, _ = roc_curve(y_test, y_pred_prob)
        roc_auc = auc(fpr, tpr)

        plt.figure(figsize=(6,6))
        plt.plot(fpr, tpr, label=f'ROC curve (AUC = {roc_auc:.2f})', color='darkorange')
        plt.plot([0, 1], [0, 1], linestyle='--', color='navy')
        plt.xlabel('False Positive Rate')
        plt.ylabel('True Positive Rate')
        plt.title('DNN ROC Curve')
        plt.legend()
        plt.grid(True)
        plt.show()

        # 3. Confusion Matrix
        cm = confusion_matrix(y_test, y_pred_class)

        plt.figure(figsize=(5,4))
        sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
                    xticklabels=['Not Churn', 'Churn'],
                    yticklabels=['Not Churn', 'Churn'])
        plt.xlabel('Predicted')
        plt.ylabel('True')
        plt.title('DNN Confusion Matrix')
        plt.show()

        print(f"Fold {fold_idx+1} Precision: {precision:.2f}")
        print(f"Fold {fold_idx+1} Recall: {recall:.2f}")
        print(f"Fold {fold_idx+1} F1 Score: {f1:.2f}")
        print(f"Fold {fold_idx+1} Accuracy: {accuracy:.2f}")

# نمایش نتایج نهایی
print("\n=== Average Results (10-Fold CV) ===")
print("Mean Accuracy (10-fold CV): {:.2f}%".format(np.mean(accuracy_scores) * 100))
print("Mean Precision (10-fold CV): {:.2f}%".format(np.mean(precision_scores) * 100))
print("Mean Recall (10-fold CV): {:.2f}%".format(np.mean(recall_scores) * 100))
print("Mean F1-Score (10-fold CV): {:.2f}%".format(np.mean(f1_scores) * 100))
# Out:
# Epoch 1/30
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1158/1158 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.8106 - loss: 0.4403 - val_accuracy: 0.8522 - val_loss: 0.3669
# Epoch 2/30
# 1158/1158 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8518 - loss: 0.3735 - val_accuracy: 0.8622 - val_loss: 0.3490
# Epoch 3/30
# 1158/1158 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8555 - loss: 0.3670 - val_accuracy: 0.8667 - val_loss: 0.3369
# Epoch 4/30
# 1158/1158 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.8536 - loss: 0.3794 - val_accuracy: 0.8644 - val_loss: 0.3570
# Epoch 5/30
# ...

# %% [markdown]
# ## DNN Compelete K_Fold
# ### Set hyperparameter Dropuot and Earlystoping

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import StratifiedKFold
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.metrics import (
    roc_curve, auc, confusion_matrix,
    precision_score, recall_score, f1_score
)

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import RMSprop
from tensorflow.keras.callbacks import EarlyStopping

# Load and preprocess dataset
dataset = pd.read_csv("/content/Churn_Modelling.csv")
dataset = dataset.drop(['RowNumber', 'CustomerId', 'Surname'], axis=1)

# Encode categorical features
for col in ['Geography', 'Gender']:
    le = LabelEncoder()
    dataset[col] = le.fit_transform(dataset[col])

# Split into features and target
X = dataset.drop("Exited", axis=1).values
y = dataset["Exited"].values

# Standardize features
scaler = StandardScaler()
X = scaler.fit_transform(X)

# Stratified 10-fold cross-validation
kfold = StratifiedKFold(n_splits=10, shuffle=True, random_state=42)
accuracy_scores = []
precision_scores = []
recall_scores = []
f1_scores = []

# Training and evaluation loop
for fold_idx, (train_index, test_index) in enumerate(kfold.split(X, y)):
    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = y[train_index], y[test_index]

    # Build the DNN model
    model = Sequential([
        Dense(10, activation='relu', input_shape=(X.shape[1],)),
        Dropout(0.1),
        Dense(6, activation='relu'),
        Dense(6, activation='relu'),
        Dense(1, activation='sigmoid')
    ])

    model.compile(optimizer=RMSprop(learning_rate=0.001),
                  loss='binary_crossentropy',
                  metrics=['accuracy'])

    early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

    history = model.fit(X_train, y_train,
                        epochs=50,
                        batch_size=32,
                        validation_split=0.1,
                        verbose=1,
                        callbacks=[early_stopping])

    # Evaluate model
    _, accuracy = model.evaluate(X_test, y_test, verbose=0)
    accuracy_scores.append(accuracy)

    # Predict probabilities and classes
    y_pred_prob = model.predict(X_test).ravel()
    y_pred_class = (y_pred_prob > 0.5).astype(int)

    # Calculate metrics
    precision = precision_score(y_test, y_pred_class)
    recall = recall_score(y_test, y_pred_class)
    f1 = f1_score(y_test, y_pred_class)

    precision_scores.append(precision)
    recall_scores.append(recall)
    f1_scores.append(f1)

    # Plot only for the first fold
    if fold_idx == 0:
        # Accuracy curve
        plt.figure(figsize=(8, 5))
        plt.plot(history.history['accuracy'], label='Train Accuracy')
        plt.plot(history.history['val_accuracy'], label='Val Accuracy')
        plt.title('DNN Accuracy over Epochs')
        plt.xlabel('Epochs')
        plt.ylabel('Accuracy')
        plt.legend()
        plt.grid(True)
        plt.show()

        # ROC curve and AUC
        fpr, tpr, _ = roc_curve(y_test, y_pred_prob)
        roc_auc = auc(fpr, tpr)

        plt.figure(figsize=(6, 6))
        plt.plot(fpr, tpr, label=f'ROC curve (AUC = {roc_auc:.2f})', color='darkorange')
        plt.plot([0, 1], [0, 1], linestyle='--', color='navy')
        plt.xlabel('False Positive Rate')
        plt.ylabel('True Positive Rate')
        plt.title('DNN ROC Curve')
        plt.legend()
        plt.grid(True)
        plt.show()

        # Confusion matrix
        cm = confusion_matrix(y_test, y_pred_class)

        plt.figure(figsize=(5, 4))
        sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
                    xticklabels=['Not Churn', 'Churn'],
                    yticklabels=['Not Churn', 'Churn'])
        plt.xlabel('Predicted')
        plt.ylabel('True')
        plt.title('DNN Confusion Matrix')
        plt.show()

# Print mean metrics over all folds
print("Mean Accuracy (10-fold CV): {:.2f}%".format(np.mean(accuracy_scores) * 100))
print("Mean Precision (10-fold CV): {:.2f}%".format(np.mean(precision_scores) * 100))
print("Mean Recall (10-fold CV): {:.2f}%".format(np.mean(recall_scores) * 100))
print("Mean F1 Score (10-fold CV): {:.2f}%".format(np.mean(f1_scores) * 100))
# Out:
# Epoch 1/50
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.7106 - loss: 0.6257 - val_accuracy: 0.8222 - val_loss: 0.4758
# Epoch 2/50
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7988 - loss: 0.4861 - val_accuracy: 0.8233 - val_loss: 0.4266
# Epoch 3/50
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8006 - loss: 0.4518 - val_accuracy: 0.8378 - val_loss: 0.4031
# Epoch 4/50
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8022 - loss: 0.4449 - val_accuracy: 0.8411 - val_loss: 0.3945
# Epoch 5/50
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8113 - loss: 0.4280 - val_accuracy: 0.8456 - val_loss: 0.3883
# ...
